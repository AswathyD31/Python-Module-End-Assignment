# %% [markdown]
# # Python Module End Assignment (Comprehensive Assessment)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset.
df = pd.read_excel(r"C:\Users\admin\Downloads\myexcel.xlsx")
df
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age               Height  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1    Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2   John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3    R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
#
#    Weight            College     Salary
# 0     180              Texas  7730337.0
# 1     235          Marquette  6796117.0
# 2     205  Boston University        NaN
# 3     185      Georgia State  1148640.0
# 4     231                NaN  5000000.0

# %%
df.tail()
# Out:
#              Name       Team  Number Position  Age               Height  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454     Raul Neto  Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455  Tibor Pleiss  Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456   Jeff Withey  Utah Jazz      24        C   26                  7-0
# 457      Priyanka  Utah Jazz      34        C   25  2023-03-07 00:00:00
#
#      Weight College     Salary
# 453     203  Butler  2433333.0
# 454     179     NaN   900000.0
# 455     256     NaN  2900000.0
# 456     231  Kansas   947276.0
# 457     231  Kansas   947276.0

# %%
# Looking at the number of rows and columns in the dataset.
df.shape
# Out:
# (458, 9)

# %%
# Names of all the columns.
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
# Names of all the columns.
for i in df.columns:
    print (i)
# Out:
# Name
# Team
# Number
# Position
# Age
# Height
# Weight
# College
# Salary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
# Basic stats about the dataset.
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  221.543668  4.833970e+06
# std     15.966837    4.400128   26.343200  5.226620e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
# Datatypes of all the columns of the dataset.
df.dtypes
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# Height       object
# Weight        int64
# College      object
# Salary      float64
# dtype: object

# %%
# To avoid settingWithCopyWarning
pd.options.mode.chained_assignment=None

# %%
x = df['Salary'].mean()
df.fillna({'Salary':x}, inplace = True)
df
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %% [markdown]
# # Preprocessing:

# %%
# Replace the 'Height' column with random numbers between 150 and 180.
df['Height'] = np.random.randint(150, 181, df.shape[0])
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     156     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     155     235
# 2     John Holland  Boston Celtics      30       SG   27     160     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     160     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     158     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     164     203
# 454      Raul Neto       Utah Jazz      25       PG   24     166     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     177     256
# 456    Jeff Withey       Utah Jazz      24        C   26     160     231
# 457       Priyanka       Utah Jazz      34        C   25     150     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %% [markdown]
# #### #Data Story: The original height values were replaced with random numbers ranging from 150 to 180 cm. This ensured data consistency and made the dataset reliable for further analysis.

# %% [markdown]
# # Analysis Tasks:

# %% [markdown]
# ## 1. Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees.

# %%
teams = df['Team'].unique()
print(teams)
# Out:
# ['Boston Celtics' 'Brooklyn Nets' 'New York Knicks' 'Philadelphia 76ers'
#  'Toronto Raptors' 'Golden State Warriors' 'Los Angeles Clippers'
#  'Los Angeles Lakers' 'Phoenix Suns' 'Sacramento Kings' 'Chicago Bulls'
#  'Cleveland Cavaliers' 'Detroit Pistons' 'Indiana Pacers'
#  'Milwaukee Bucks' 'Dallas Mavericks' 'Houston Rockets'
#  'Memphis Grizzlies' 'New Orleans Pelicans' 'San Antonio Spurs'
#  'Atlanta Hawks' 'Charlotte Hornets' 'Miami Heat' 'Orlando Magic'
#  'Washington Wizards' 'Denver Nuggets' 'Minnesota Timberwolves'
#  'Oklahoma City Thunder' 'Portland Trail Blazers' 'Utah Jazz']

# %%
# Calculate the distribution of employees across each team
team_distribution = df['Team'].value_counts()
team_distribution
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
total_employees=len(df)
print(total_employees)
# Out:
# 458

# %%
# Calculate the percentage split relative to the total number of employees
team_distribution_percentage = (team_distribution / df.shape[0]) * 100
team_distribution_percentage
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
team_distribution_df = pd.DataFrame({
    'Count': team_distribution,
    'Percentage': team_distribution_percentage
}).reset_index().rename(columns={'index': 'Team'})

# %%
team_distribution_df
# Out:
#                       Team  Count  Percentage
# 0     New Orleans Pelicans     19    4.148472
# 1        Memphis Grizzlies     18    3.930131
# 2                Utah Jazz     16    3.493450
# 3          New York Knicks     16    3.493450
# 4          Milwaukee Bucks     16    3.493450
# 5            Brooklyn Nets     15    3.275109
# 6   Portland Trail Blazers     15    3.275109
# 7    Oklahoma City Thunder     15    3.275109
# 8           Denver Nuggets     15    3.275109
# 9       Washington Wizards     15    3.275109
# 10              Miami Heat     15    3.275109
# 11       Charlotte Hornets     15    3.275109
# 12           Atlanta Hawks     15    3.275109
# 13       San Antonio Spurs     15    3.275109
# 14         Houston Rockets     15    3.275109
# 15          Boston Celtics     15    3.275109
# 16          Indiana Pacers     15    3.275109
# 17         Detroit Pistons     15    3.275109
# 18     Cleveland Cavaliers     15    3.275109
# ...

# %% [markdown]
# # Graphical Representation:

# %%
#Visualizing the results.
plt.figure(figsize=(12, 8))
sns.barplot(x='Count', y='Team', hue='Team', data=team_distribution_df, palette='viridis', dodge=False, legend=False)
plt.xlabel('Number of Employees')
plt.ylabel('Team')
plt.title('Distribution of Employees Across Teams')
plt.show()

# %%
#Total number of teams.
print("Total number of teams=",len(team_distribution))
# Out:
# Total number of teams= 30

# %% [markdown]
# # Graphical Representation:

# %%
#Visualizing the results.
plt.figure(figsize=(55,25),dpi=30)
x=team_distribution_percentage.index
y=team_distribution_percentage.values
plt.bar(x, y, color=['red','purple'],width=0.5)
plt.xticks(fontsize=35)
plt.xticks(rotation=90)
plt.yticks(fontsize=35)
plt.title('Percentage split of employees in each team',size=45)
plt.xlabel('Team',size=45)
plt.ylabel('Percentage',size=45)
plt.show()

# %% [markdown]
# #### #Data Story: The distribution of employees across teams is fairly uniform, with a few teams having slightly more employees.

# %% [markdown]
# ## 2. Segregate employees based on their positions within the company.

# %%
# Position Segregation
position_distribution = df.groupby(['Position', 'Name']).sum()
position_distribution
# Out:
#                                           Team  Number  Age  Height  Weight  \
# Position Name
# C        Al Horford              Atlanta Hawks      15   30     175     245
#          Al Jefferson        Charlotte Hornets      25   31     167     289
#          Alan Williams            Phoenix Suns      15   23     171     260
#          Alex Len                 Phoenix Suns      21   22     153     260
#          Alexis Ajinca    New Orleans Pelicans      42   28     167     248
# ...                                        ...     ...  ...     ...     ...
# SG       Tyreke Evans     New Orleans Pelicans       1   26     169     220
#          Victor Oladipo          Orlando Magic       5   24     170     210
#          Vince Carter        Memphis Grizzlies      15   39     176     220
#          Wayne Ellington         Brooklyn Nets      21   28     163     200
#          Wesley Matthews      Dallas Mavericks      23   29     161     220
#
# ...

# %%
#Count of employees working in each position.
position_distribution = df['Position'].value_counts()
print("Number of positions in players are:")
position_distribution
# Out:
# Number of positions in players are:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %% [markdown]
# # Graphical Representation:

# %%
#Visualizing the results.
plt.figure(figsize=(6,5))
plt.bar(position_distribution.index,position_distribution.values,color='green')
plt.xlabel('Player Position')
plt.ylabel('Number of employees/players')
plt.title('Employees Position Distribution')
plt.grid(True)
plt.show()

# %% [markdown]
# #### #Data Story: Certain positions, such as guards and forwards, have a higher count of employees.

# %% [markdown]
# ## 3. Identify the predominant age group among employees.

# %%
age = df['Age'].value_counts()
age
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
#The predominant age among employees.
predominant_age = age.idxmax()
print("The predominant age among employees is", predominant_age)
# Out:
# The predominant age among employees is 24

# %% [markdown]
# # Graphical Representation:

# %%
#Visualizing.
plt.figure(figsize=(12, 8))
plt.pie(age, labels=age.index, autopct='%1.2f%%',colors=sns.color_palette('Blues'), radius=1)
plt.title('Distribution of Employees Across Age ')
plt.show()

# %% [markdown]
# #### #Data Story: The most predominant age among employees at ABC Company is 25 and the predominant age group among employees is 20-30, indicating a young and dynamic workforce that brings fresh perspectives and potential for long-term career growth within the organization.

# %%
#The predominant age group among employees.
df['Age Group'] = df['Age'].apply(lambda age:'20-25' if 20 <= age <= 25 else ('26-30' if 26 <= age <= 30 else ('31-35' if 31 <= age <= 35 else '36 -40')))
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     156     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     155     235
# 2     John Holland  Boston Celtics      30       SG   27     160     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     160     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     158     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     164     203
# 454      Raul Neto       Utah Jazz      25       PG   24     166     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     177     256
# 456    Jeff Withey       Utah Jazz      24        C   26     160     231
# 457       Priyanka       Utah Jazz      34        C   25     150     231
#
#                College        Salary Age Group
# ...

# %%
df["Age Group"].value_counts()
# Out:
# Age Group
# 20-25     198
# 26-30     167
# 31-35      68
# 36 -40     25
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,5))
sns.countplot(x="Age Group",data = df,palette = "magma",hue = "Age Group")
plt.title('Employees Age Group Distribution')
plt.grid(True)

# %% [markdown]
# #### #Data story:In this counterplot analysis based on extraction of employee wrt age reveals that,majority of employees about 198 individuals are under the age between 20-25.of course,there are fewer individuals specifically 25 employees are within the age range betweeen 36-40.

# %% [markdown]
# ## 4. Discover which team and position have the highest salary expenditure.

# %%
team_salary_expenditure = df.groupby('Team')['Salary'].sum().sort_values(ascending=False)
team_salary_expenditure
# Out:
# Team
# Cleveland Cavaliers       1.118227e+08
# Memphis Grizzlies         9.588676e+07
# Los Angeles Clippers      9.485464e+07
# Oklahoma City Thunder     9.376530e+07
# Miami Heat                9.218361e+07
# Golden State Warriors     8.886900e+07
# Chicago Bulls             8.678338e+07
# San Antonio Spurs         8.444273e+07
# New Orleans Pelicans      8.275077e+07
# Charlotte Hornets         7.834092e+07
# Washington Wizards        7.632864e+07
# Houston Rockets           7.528302e+07
# New York Knicks           7.330390e+07
# Atlanta Hawks             7.290295e+07
# Los Angeles Lakers        7.177043e+07
# Sacramento Kings          7.168367e+07
# Dallas Mavericks          7.119873e+07
# Toronto Raptors           7.111761e+07
# Milwaukee Bucks           6.960352e+07
# Detroit Pistons           6.716826e+07
# Indiana Pacers            6.675183e+07
# Denver Nuggets            6.495590e+07
# Minnesota Timberwolves    6.454367e+07
# Utah Jazz                 6.400737e+07
# ...

# %%
team_salary_expenditure.head(1)
# Out:
# Team
# Cleveland Cavaliers    1.118227e+08
# Name: Salary, dtype: float64

# %% [markdown]
# # Graphical Representation:

# %%
# Visualization for Salary Expenditure by Team.
sns.barplot(x=team_salary_expenditure.values,hue=y, y=team_salary_expenditure.index, palette='viridis')
plt.xlabel('Total Salary Expenditure')
plt.ylabel('Team')
plt.title('Total Salary Expenditure by Team')
plt.show()

# %% [markdown]
# ## Highest Salary Expenditure: The team and position with the highest salary expenditure are clearly identifiable.

# %%
position_salary_expenditure = df.groupby('Position')['Salary'].sum().sort_values(ascending=False)
position_salary_expenditure
# Out:
# Position
# C     4.663773e+08
# PG    4.661848e+08
# PF    4.570628e+08
# SF    4.128549e+08
# SG    4.114782e+08
# Name: Salary, dtype: float64

# %%
highest_spending_salary = team_salary_expenditure.max()
highest_spending_salary
# Out:
# 111822658.5458613

# %% [markdown]
# # Graphical Representation:

# %%
# Visualization for Salary Expenditure by Position
plt.figure(figsize=(6, 5))
position_salary_expenditure.plot(kind='bar', color='purple')
plt.xlabel('Position')
plt.ylabel('Total Salary Expenditure')
plt.title('Total Salary Expenditure by Position')
plt.grid(True)
plt.show()

# %% [markdown]
# #### #Data Story: The Cleveland Cavaliers have the highest team salary expenditure, while the C (Center) position incurs the highest overall salary cost within ABC Company.

# %% [markdown]
# ## 5. Investigate if there's any correlation between age and salary, and represent it visually.

# %%
df1 = df[["Age","Salary"]]
df1
# Out:
#      Age        Salary
# 0     25  7.730337e+06
# 1     25  6.796117e+06
# 2     27  4.833970e+06
# 3     22  1.148640e+06
# 4     29  5.000000e+06
# ..   ...           ...
# 453   26  2.433333e+06
# 454   24  9.000000e+05
# 455   26  2.900000e+06
# 456   26  9.472760e+05
# 457   25  9.472760e+05
#
# [458 rows x 2 columns]

# %%
#Correlation
Correlation = df['Age'].corr(df['Salary'])
print("The Correlation between age and salary is", Correlation)
# Out:
# The Correlation between age and salary is 0.21116954917686373

# %%
#ScatterPlot vizualisation.
age = df['Age']
salary = df['Salary']
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Correlation between Age and Salary")
sns.scatterplot(x=age,y=salary,hue=age,palette='husl')
plt.show()

# %% [markdown]
# #### #Data Story: There is a positive correlation between age and salary, indicating that older employees generally earn higher salaries, although there are high-earning younger employees as well, reflecting the impact of exceptional performance or specific roles.
